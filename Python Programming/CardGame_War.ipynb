# %%
import random
suits = ('Hearts','Diamond','Spade','Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

class Card:
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + ' of '+ self.suit
    
class Deck():
    def __init__(self):
        self.all_cards= []
        
        for suit in suits:
            for rank in ranks:
                created_card = Card(suit,rank)
                self.all_cards.append(created_card)
                
    def shuffle(self):
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()
    
class Player():
    def __init__(self, name):
        self.name = name
        self.all_cards = []
        
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards.'
        
    def remove_card(self):
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)

# %%
# GAME SETUP
new_deck = Deck()
new_deck.shuffle()

player_one = Player('ONE')
player_two = Player('TWO')

for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())
    
game_on = True
round_num = 0

while game_on:
    round_num += 1
    print(f'Round number:{round_num}')
    
    if len(player_one.all_cards) == 0:
        print('Player ONE, is out of cards. Player TWO wins!!')
        game_on = False
        break
    if len(player_two.all_cards) == 0:
        print('Player TWO, is out of cards. Player ONE wins!!')
        game_on = False
        break
        
    # Start a New Round
    player_one_cards = []
    player_one_cards.append(player_one.remove_card())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_card())
    
    # While at war
    at_war = True
    
    while at_war:
        if player_one_cards[-1].value < player_two_cards[-1].value:
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            print('Player 2 has bigger card')
            at_war = False
            
        elif player_one_cards[-1].value > player_two_cards[-1].value:
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            print('Player 1 has bigger card')
            at_war = False
            
        else:
            print('WAR!!')
            if len(player_one.all_cards) <5:
                print('Player one doesnot have enough cards and LOSES!!(Unable to declare war)')
                print('Player TWO Wins!!')
                game_on = False
                break
            elif len(player_two.all_cards) <5:
                print('Player two doesnot have enough cards and LOSES!!(Unable to declare war)')
                print('Player ONE Wins!!')
                game_on = False
                break
            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_card())
                    player_two_cards.append(player_two.remove_card())
# Out:
# Round number:1
# Player 2 has bigger card
# Round number:2
# Player 2 has bigger card
# Round number:3
# Player 1 has bigger card
# Round number:4
# Player 2 has bigger card
# Round number:5
# Player 1 has bigger card
# Round number:6
# Player 1 has bigger card
# Round number:7
# Player 1 has bigger card
# Round number:8
# Player 2 has bigger card
# Round number:9
# Player 1 has bigger card
# Round number:10
# Player 1 has bigger card
# Round number:11
# Player 2 has bigger card
# Round number:12
# Player 2 has bigger card
# Round number:13
# Player 1 has bigger card
# Round number:14
# Player 1 has bigger card
# Round number:15
# Player 2 has bigger card
# Round number:16
# Player 1 has bigger card
# Round number:17
# Player 1 has bigger card
# Round number:18
# Player 1 has bigger card
# Round number:19
# Player 1 has bigger card
# Round number:20
# Player 2 has bigger card
# Round number:21
# Player 2 has bigger card
# Round number:22
# Player 1 has bigger card
# Round number:23
# ...
